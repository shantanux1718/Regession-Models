# %% [markdown]
# 🟢#HR finding Bluffing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
import sklearn.linear_model
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
bluff = pd.read_csv("https://raw.githubusercontent.com/yash240990/Python/master/Position_Salaries.csv")
bluff
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
bluff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %% [markdown]
# #simple linear regression

# %%
x = bluff.Level.values[:,np.newaxis]
y = bluff.Salary.values

# %%
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
prevalue = lin_reg.predict(x)
mat.scatter(x,y,color='red')
mat.plot(x,prevalue,color='green',label='Regression line')
mat.title('Bluff model using SLR')
mat.xlabel('Level')
mat.ylabel('Salaries')
mat.legend()
mat.show()

# %%
#Polynomial Regression :
#1st we increase degree of polynomial variable then we train model

# %% [markdown]
# #Polynomial Regression with degree=2

# %%
#Build Model using Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
preg = PolynomialFeatures(degree=2)
xpoly2 = preg.fit_transform(x)
xpoly2

'''
when degree=2
matrix will be
col1  = 1,2,3,....
col2 = x*1
col2 = x*x
'''

'''
when degree=3
matrix will be
col1  = 1,2,3,....
col2 = x*1
col2 = x*x
col3 = x*x*x
'''

'''
when degree=4
matrix will be
col1  = 1,2,3,4....
col2 = x*1
col2 = x*x
col3 = x*x*x
col4 = x*x*x*x
'''
# Out:
# '\nwhen degree=4 \nmatrix will be\ncol1  = 1,2,3,4....\ncol2 = x*1 \ncol2 = x*x\ncol3 = x*x*x\ncol4 = x*x*x*x\n'

# %%
lin_reg.fit(xpoly2,y)
# Out:
# LinearRegression()

# %%
prevalue = lin_reg.predict(xpoly2)
mat.scatter(x,y,color='red')
mat.plot(x,prevalue,color='green',label='Regression line')
mat.title('Bluff model using Polynomial Regression with degree=2')
mat.xlabel('Level')
mat.ylabel('Salaries')
mat.legend()
mat.show()

# %% [markdown]
# #Polynomial Regression with degree=3

# %%
preg = PolynomialFeatures(degree=3)
xpoly3 = preg.fit_transform(x)
xpoly3
# Out:
# array([[   1.,    1.,    1.,    1.],
#        [   1.,    2.,    4.,    8.],
#        [   1.,    3.,    9.,   27.],
#        [   1.,    4.,   16.,   64.],
#        [   1.,    5.,   25.,  125.],
#        [   1.,    6.,   36.,  216.],
#        [   1.,    7.,   49.,  343.],
#        [   1.,    8.,   64.,  512.],
#        [   1.,    9.,   81.,  729.],
#        [   1.,   10.,  100., 1000.]])

# %%
lin_reg.fit(xpoly3,y)
# Out:
# LinearRegression()

# %%
prevalue = lin_reg.predict(xpoly3)
mat.scatter(x,y,color='red')
mat.plot(x,prevalue,color='green',label='Regression line')
mat.title('Bluff model using Polynomial Regression with degree=3')
mat.xlabel('Level')
mat.ylabel('Salaries')
mat.legend()
mat.show()

# %% [markdown]
# #Polynomial Regression with degree=4

# %%
preg = PolynomialFeatures(degree=4)
xpoly4 = preg.fit_transform(x)
xpoly4
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01, 8.100e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01, 2.560e+02],
#        [1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02, 6.250e+02],
#        [1.000e+00, 6.000e+00, 3.600e+01, 2.160e+02, 1.296e+03],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02, 2.401e+03],
#        [1.000e+00, 8.000e+00, 6.400e+01, 5.120e+02, 4.096e+03],
#        [1.000e+00, 9.000e+00, 8.100e+01, 7.290e+02, 6.561e+03],
#        [1.000e+00, 1.000e+01, 1.000e+02, 1.000e+03, 1.000e+04]])

# %%
lin_reg.fit(xpoly4,y)
# Out:
# LinearRegression()

# %%
prevalue = lin_reg.predict(xpoly4)
mat.scatter(x,y,color='red')
mat.plot(x,prevalue,color='green',label='Regression line')
mat.title('Bluff model using Polynomial Regression with degree=3')
mat.xlabel('Level')
mat.ylabel('Salaries')
mat.legend()
mat.show()

# %%
level = int(input('Enter the level Number'))
prediction = lin_reg.predict(preg.fit_transform([[level]]))
print('For level',level,'Salary will be',int(prediction[0]))
# Out:
# Enter the level Number6
# For level 6 Salary will be 152736
